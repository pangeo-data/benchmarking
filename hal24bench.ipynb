# %%
from benchmarks.utils import PBSSetup
#import warnings
#warnings.simplefilter("ignore") # Silence warnings

# %%
s = PBSSetup('hal24.yaml')
#s = PBSSetup('setup.yaml')

# %%
for i in range(1):
    s.run(verbose=True)
# Out:
# read configuration yaml file here to run the benchmarks
#  Creates a dask cluster using dask_jobqueue
# memory size for each node:  128gb
# number of cores for each node:  24
# number of workers for each node:  4
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/dask_jobqueue/config.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/deploy/local.py:138: UserWarning: diagnostics_port has been deprecated. Please use `dashboard_address=` instead
#   "diagnostics_port has been deprecated. "
# job script created by dask_jobqueue: starts--------
# #!/bin/bash
#
# #!/usr/bin/env bash
# #PBS -N dask-worker
# #PBS -q batch
# #PBS -l select=1:ncpus=24:mem=120GB
# #PBS -l walltime=3600
# #PBS -j oe
# JOB_ID=${PBS_JOBID%.*}
#
#
#
# /home/mp/odakat/miniconda3/envs/pangeobench/bin/python -m distributed.cli.dask_worker tcp://10.135.39.56:47395 --nthreads 6 --nprocs 4 --memory-limit 32.00GB --name dask-worker--${JOB_ID}-- --death-timeout 60 --local-directory $TMPDIR --interface ib0
#
# job script created by dask_jobqueue: ends --------
# dask cluster dashboard_link :
# http://10.135.39.56:8787/status
# start cluster_wait
# dask cluster client started  with 2 nodes
# client cluster
# 8
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=64MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(521, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=64MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(66, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=64MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(199, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(1042, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(317, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(463, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=2, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(926, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24/compute_study_2019-08-10_1536.29_.csv
# start cluster_wait
# dask cluster client started  with 4 nodes
# client cluster
# 16
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=64MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(1042, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=64MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(66, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=64MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(199, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(317, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(463, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=4, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(1041, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24/compute_study_2019-08-10_1538.18_.csv
# start cluster_wait
# dask cluster client started  with 6 nodes
# client cluster
# 24
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=64MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1563)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1984-04-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1563, 384, 320), chunksize=(1563, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=64MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1563)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1984-04-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1563, 384, 320), chunksize=(66, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=64MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1563)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1984-04-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1563, 384, 320), chunksize=(199, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(3125, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(6250, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 18 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(250, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(12500, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 35 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(500, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 25000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2048-06-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(25000, 384, 320), chunksize=(25000, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 24.6 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 69 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 25000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2048-06-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(25000, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 24.6 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=6, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 25000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2048-06-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(25000, 384, 320), chunksize=(1000, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 24.6 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24/compute_study_2019-08-10_1540.25_.csv
# start cluster_wait
# dask cluster client started  with 8 nodes
# client cluster
# 32
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=64MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 62, 62)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=64MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(66, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=64MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(199, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 62, 62)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 62, 62)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(317, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 62, 62)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(520, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(33334, 62, 62)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 92 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=4, num_nodes=8, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(1041, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24/compute_study_2019-08-10_1542.51_.csv
# client and cluster close before changing number of workers per nodes
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1af31fd488>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1ad3e69ea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1aefa02c80>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1af44df378>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1af78aa048>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2b1ad35ae6a8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-5fa227f8-bb84-11e9-af13-db759ad8b9b5'
# ...
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2116-11-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(50000, 384, 320), chunksize=(50000, 36, 36)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 49.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 137 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=6, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 50000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2116-11-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(50000, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 49.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=6, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 50000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2116-11-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(50000, 384, 320), chunksize=(500, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 49.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=6, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 100000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2253-10-15
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(100000, 384, 320), chunksize=(100000, 36, 36)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 98.3 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 274 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=6, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 100000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2253-10-15
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(100000, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 98.3 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=6, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 100000)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2253-10-15
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(100000, 384, 320), chunksize=(1000, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 98.3 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24/compute_study_2019-08-10_1644.39_.csv
# start cluster_wait
# dask cluster client started  with 8 nodes
# client cluster
# 128
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=64MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 31, 31)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=64MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(66, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=64MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(199, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 31, 31)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(33334, 31, 31)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 92 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(317, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(66667, 31, 31)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 183 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(409, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=16, num_nodes=8, chunk_size=1024MB, chunking_scheme=spatial
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-3-843ab876b304> in <module>
#       1 for i in range(1):
# ----> 2     s.run(verbose=True)
#
# ~/git/benchmarking/benchmarks/utils.py in run(self, verbose)
#     111                             chunking_scheme=chunking_scheme,
#     112                             num_nodes=num,
# --> 113                             worker_per_node=wpn,
#     114                         ).persist()
#     115                         wait(ds)
#
# ~/git/benchmarking/benchmarks/datasets.py in timeseries(chunk_size, num_nodes, worker_per_node, chunking_scheme, lat, lon, start, freq, nan)
#      86     lats = xr.DataArray(np.linspace(start=-90, stop=90, num=lat), dims=['lat'])
#      87     lons = xr.DataArray(np.linspace(start=-180, stop=180, num=lon), dims=['lon'])
# ---> 88     times = xr.DataArray(pd.date_range(start=start, freq=freq, periods=timesteps), dims=['time'])
#      89     if chunks == 'auto':
#      90         with dask.config.set({'array.chunk-size': chunk_size}):
#
# ~/miniconda3/envs/pangeobench/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    1522         start=start, end=end, periods=periods,
#    1523         freq=freq, tz=tz, normalize=normalize,
# -> 1524         closed=closed, **kwargs)
#    1525     return DatetimeIndex._simple_new(
#    1526         dtarr, tz=dtarr.tz, freq=dtarr.freq, name=name)
#
# ~/miniconda3/envs/pangeobench/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, closed)
#     446                     end = end.tz_localize(None)
#     447             # TODO: consider re-implementing _cached_range; GH#17914
# --> 448             values, _tz = generate_regular_range(start, end, periods, freq)
#     449             index = cls._simple_new(values, freq=freq, dtype=tz_to_dtype(_tz))
#     450
#
# ~/miniconda3/envs/pangeobench/lib/python3.6/site-packages/pandas/core/arrays/_ranges.py in generate_regular_range(start, end, periods, freq)
#      44         elif start is not None:
#      45             b = Timestamp(start).value
# ---> 46             e = _generate_range_overflow_safe(b, periods, stride, side='start')
#      47             tz = start.tz
#      48         elif end is not None:
#
# ~/miniconda3/envs/pangeobench/lib/python3.6/site-packages/pandas/core/arrays/_ranges.py in _generate_range_overflow_safe(endpoint, periods, stride, side)
#     130           (endpoint < 0 and side == 'end' and stride > 0)):
#     131         # no chance of not-overflowing
# --> 132         raise OutOfBoundsDatetime(msg)
#     133
#     134     elif (side == 'end' and endpoint > i64max and endpoint - stride <= i64max):
#
# OutOfBoundsDatetime: Cannot generate range with start=315532800000000000 and periods=133334

# %%
s.client.cluster.close()
