# %%
from benchmarks.utils import PBSSetup
#import warnings
#warnings.simplefilter("ignore") # Silence warnings

# %%
s = PBSSetup('hal24test.yaml')
#s = PBSSetup('setup.yaml')

# %%
for i in range(1):
    s.run(verbose=True)
# Out:
# read configuration yaml file here to run the benchmarks
#  Creates a dask cluster using dask_jobqueue
# memory size for each node:  128gb
# number of cores for each node:  24
# number of workers for each node:  12
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/dask_jobqueue/config.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/deploy/local.py:138: UserWarning: diagnostics_port has been deprecated. Please use `dashboard_address=` instead
#   "diagnostics_port has been deprecated. "
# job script created by dask_jobqueue: starts--------
# #!/bin/bash
#
# #!/usr/bin/env bash
# #PBS -N dask-worker
# #PBS -q batch
# #PBS -l select=1:ncpus=24:mem=120GB
# #PBS -l walltime=3600
# #PBS -j oe
# JOB_ID=${PBS_JOBID%.*}
#
#
#
# /home/mp/odakat/miniconda3/envs/pangeobench/bin/python -m distributed.cli.dask_worker tcp://10.135.39.56:57482 --nthreads 2 --nprocs 12 --memory-limit 10.67GB --name dask-worker--${JOB_ID}-- --death-timeout 60 --local-directory $TMPDIR --interface ib0
#
# job script created by dask_jobqueue: ends --------
# dask cluster dashboard_link :
# http://10.135.39.56:8787/status
# start cluster_wait
# dask cluster client started  with 2 nodes
# client cluster
# 24
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(3125, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 3125)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1988-07-21
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(3125, 384, 320), chunksize=(251, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 3.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(6250, 72, 72)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 18 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=2, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(250, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24test/compute_study_2019-08-09_1542.23_.csv
# start cluster_wait
# dask cluster client started  with 4 nodes
# client cluster
# 48
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=128MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(6250, 51, 51)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 18 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=128MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(131, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=128MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 6250)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1997-02-09
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(6250, 384, 320), chunksize=(250, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 6.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=256MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(12500, 51, 51)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 35 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=256MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(261, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=12, num_nodes=4, chunk_size=256MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 12500)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2014-03-22
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(12500, 384, 320), chunksize=(250, 192, 160)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 12.3 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24test/compute_study_2019-08-09_1543.08_.csv
# client and cluster close before changing number of workers per nodes
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2832b2f0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc291b0e18>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a2340d0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a9009d8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a180ae8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0eb3a7b8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc28330840>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2b041510>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2b1daf28>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e2510>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e4400>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a213048>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a218598>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ef53ea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a2188c8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1d60d0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1d62f0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1fe488>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1fea60>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1bdf28>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1c82f0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc29cb79d8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a21da60>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a226378>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a226ae8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a223ea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2c433268>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2c4338c8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2c433950>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0f8fcc80>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a3320d0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a24a7b8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a33cea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a553c80>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a325048>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0e4cdbf8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ea13ea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ea13d08>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ea13840>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0e42e9d8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0e42e400>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0f5d7840>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0dee3268>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2ab80d90>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2ab80f28>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2ab80950>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ea1c378>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ea1c598>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc0ee69c80>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# ...
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a2182f0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a218488>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a218f28>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a218620>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a213bf8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a213a60>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a213c80>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a213d08>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e4268>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e4048>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e2400>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e2ae8>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a1e2f28>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a185ea0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a185840>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a185d90>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2989e1e0>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc2a185620>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc28bb0048>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# tornado.application - ERROR - Exception in callback functools.partial(<function Scheduler.cancel_key.<locals>.<lambda> at 0x2adc28fa8158>, <Future finished result=None>)
# Traceback (most recent call last):
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1981, in <lambda>
#     gen.sleep(0.2), lambda _: self.cancel_key(key, client, retries - 1)
#   File "/home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/scheduler.py", line 1977, in cancel_key
#     cs = self.clients[client]
# KeyError: 'Client-353d0d92-babc-11e9-8c0a-cbaa52598c7f'
# client cluster close finished
# client  close finished

# %%
s.client.cluster.close()
