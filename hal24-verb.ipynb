# %%
from benchmarks.utils import PBSSetup
#import warnings
#warnings.simplefilter("ignore") # Silence warnings

# %%
s = PBSSetup('hal24.yaml')
#s = PBSSetup('setup.yaml')

# %%
for i in range(1):
    s.run(verbose=True)
# Out:
# read configuration yaml file here to run the benchmarks
#  Creates a dask cluster using dask_jobqueue
# memory size for each node:  128gb
# number of cores for each node:  24
# number of workers for each node:  1
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/dask_jobqueue/config.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/distributed/deploy/local.py:138: UserWarning: diagnostics_port has been deprecated. Please use `dashboard_address=` instead
#   "diagnostics_port has been deprecated. "
# job script created by dask_jobqueue: starts--------
# #!/bin/bash
#
# #!/usr/bin/env bash
# #PBS -N dask-worker
# #PBS -q batch
# #PBS -l select=1:ncpus=24:mem=120GB
# #PBS -l walltime=3600
# #PBS -j oe
# JOB_ID=${PBS_JOBID%.*}
#
# OMP_NUM_THREADS=1
#
# /home/mp/odakat/miniconda3/envs/pangeobench/bin/python -m distributed.cli.dask_worker tcp://10.135.39.58:40322 --nthreads 24 --memory-limit 128.00GB --name dask-worker--${JOB_ID}-- --death-timeout 60 --local-directory $TMPDIR --nthreads 1 --interface ib0
#
# job script created by dask_jobqueue: ends --------
# dask cluster dashboard_link :
# http://10.135.39.58:8787/status
# start cluster_wait
# dask cluster client started  with 1 nodes
# client cluster
# 1
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(521, 351, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 521)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1981-06-04
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(521, 384, 320), chunksize=(520, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 0.5 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(1042, 351, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=2048MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 351, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=2048MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=2048MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=4096MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 351, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=4096MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=1, chunk_size=4096MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4166, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24-1thread/compute_study_2019-08-21_0942.16_.csv
# start cluster_wait
# dask cluster client started  with 2 nodes
# client cluster
# 2
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(1042, 248, 248)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 1042)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1982-11-07
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(1042, 384, 320), chunksize=(520, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 1.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 248, 248)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=2048MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 248, 248)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=2048MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(2084, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=2048MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(1389, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=4096MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 248, 248)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=4096MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(4167, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=2, chunk_size=4096MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(2778, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24-1thread/compute_study_2019-08-21_0947.31_.csv
# start cluster_wait
# dask cluster client started  with 4 nodes
# client cluster
# 4
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(2084, 176, 176)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 2084)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1985-09-14
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(2084, 384, 320), chunksize=(520, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 2.0 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 176, 176)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(1041, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=2048MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 176, 176)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=2048MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(2084, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=2048MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(1389, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=4096MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 176, 176)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=4096MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(4167, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=4, chunk_size=4096MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(2381, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24-1thread/compute_study_2019-08-21_0952.54_.csv
# start cluster_wait
# dask cluster client started  with 8 nodes
# client cluster
# 8
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(4167, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 4167)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 1991-05-29
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(4167, 384, 320), chunksize=(463, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 4.1 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(926, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=2048MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=2048MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(2084, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=2048MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(2083, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=4096MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(33334, 124, 124)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 92 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=4096MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(4167, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=8, chunk_size=4096MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(2381, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24-1thread/compute_study_2019-08-21_0959.15_.csv
# start cluster_wait
# dask cluster client started  with 16 nodes
# client cluster
# 16
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=512MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(8334, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 23 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=512MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(521, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=512MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 8334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2002-10-25
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(8334, 384, 320), chunksize=(463, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 8.2 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=1024MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(16667, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 46 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=1024MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(1042, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=1024MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 16667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2025-08-18
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(16667, 384, 320), chunksize=(1041, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 16.4 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=2048MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(33334, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 92 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=2048MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(2084, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=2048MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 33334)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2071-04-06
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(33334, 384, 320), chunksize=(2083, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 32.8 GB
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=4096MB, chunking_scheme=spatial
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(66667, 88, 88)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 183 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=4096MB, chunking_scheme=temporal
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(4167, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# benchmark start with: worker_per_node=1, num_nodes=16, chunk_size=4096MB, chunking_scheme=auto
# <xarray.Dataset>
# Dimensions:  (lat: 320, lon: 384, time: 66667)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2162-07-11
#   * lon      (lon) float64 -180.0 -179.1 -178.1 -177.2 ... 178.1 179.1 180.0
#   * lat      (lat) float64 -90.0 -89.44 -88.87 -88.31 ... 88.31 88.87 89.44 90.0
# Data variables:
#     sst      (time, lon, lat) float64 dask.array<shape=(66667, 384, 320), chunksize=(4166, 384, 320)>
# Attributes:
#     history:  created for compute benchmarking
#
#  datasize: 65.5 GB
# /home/mp/odakat/miniconda3/envs/pangeobench/lib/python3.6/site-packages/xarray/core/indexing.py:1195: PerformanceWarning: Slicing with an out-of-order index is generating 12 times more chunks
#   return self.array[key]
# kills ds and every other dependent computation
# create bench mark result file:  ./results-hal24-1thread/compute_study_2019-08-21_1007.47_.csv
# client and cluster close before changing number of workers per nodes
# client cluster close finished
# client  close finished

# %%
import dask

# %%
dask.config.get("jobqueue.pbs")
# Out:
# {'name': 'dask-worker',
#  'cores': None,
#  'memory': None,
#  'processes': 1,
#  'interface': None,
#  'death-timeout': 60,
#  'local-directory': None,
#  'queue': None,
#  'project': None,
#  'walltime': '00:30:00',
#  'extra': [],
#  'env-extra': [],
#  'resource-spec': None,
#  'job-extra': [],
#  'log-directory': None}
